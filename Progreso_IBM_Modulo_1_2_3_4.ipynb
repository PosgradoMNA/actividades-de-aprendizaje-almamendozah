# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-almamendozah/blob/main/Progreso_IBM_Modulo_1_2_3_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('assignment01 for GitJobish03 and edited in git, and 18')
# Out:
# assignment01 for GitJobish03 and edited in git, and 18

# %%
#Progreso Python for Data Science
#Alma Fabiola Mendoza Huerta
#A00826804

# %% [markdown]
# ![Captura de Pantalla 2022-10-17 a la(s) 1.46.03.png](data:image/png;base64,...)
